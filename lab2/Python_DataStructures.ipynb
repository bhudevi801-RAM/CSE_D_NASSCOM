# %% [markdown]
# # 🐍 Python Data Structures & File Handling — Lab Manual
#
# ### For B.Tech II Year CSE Students | AI/ML & Programming Practical
#
# Full explanations, function tables, and brainstorm challenges are in the companion file:
# **`Python_DataStructures_Definitions.md`** — read the matching section there before each Demo.
#
# **How to use this notebook:**
# 1. Read the matching section in the definitions file first.
# 2. Run each **Demo** cell.
# 3. Complete the **Practice** cell (replace every `# TODO`).
#
# **Topics:** Lists → Tuples → Dictionaries → Sets → File Handling
#
# ---

# %% [markdown]
# ## 1️⃣ Lists
# *(see Definitions.md → Lists for the why/when/function table)*

# %%
# ------------------------------------------------------------- #
# 🔹 1. LISTS — DEMO
# ------------------------------------------------------------- #

students = ["Anika", "Bhavya", "Chetan", "Divya"]

students.append("Esha")
print("After append:", students)

students.insert(1, "Farah")
print("After insert:", students)

students.remove("Chetan")
print("After remove:", students)

last_student = students.pop()
print("Removed via pop:", last_student, "| Remaining:", students)

students.sort()
print("Sorted:", students)

print("Total students:", len(students))

top_two = students[:2]
print("Top two (sliced):", top_two)

# %% [markdown]
# ### 📝 Practice — Lists

# %%
# ------------------------------------------------------------- #
# 🔹 1. LISTS — PRACTICE
# ------------------------------------------------------------- #

marks = [56, 78, 90, 45, 88, 90, 67]

# TODO 1: Add a new mark of 99 to the END of the list


# TODO 2: Remove the mark 45 BY VALUE


# TODO 3: Sort the marks in DESCENDING order


# TODO 4: Count how many times 90 appears


# TODO 5: Print only the top 3 marks using slicing


print("Final marks list:", marks)

# %% [markdown]
# ## 2️⃣ Tuples
# *(see Definitions.md → Tuples for the why/when/function table)*

# %%
# ------------------------------------------------------------- #
# 🔹 2. TUPLES — DEMO
# ------------------------------------------------------------- #

student_record = (101, "Anika", "CSE")

roll_no, name, dept = student_record
print(f"Roll: {roll_no}, Name: {name}, Dept: {dept}")

try:
    student_record[1] = "Bhavya"
except TypeError as e:
    print("Cannot modify a tuple! Error:", e)

def get_min_max(numbers):
    return min(numbers), max(numbers)

lowest, highest = get_min_max([56, 78, 90, 45])
print("Lowest:", lowest, "| Highest:", highest)

grades = ("A", "B", "A", "C", "A", "B")
print("Number of A grades:", grades.count("A"))
print("Position of first C grade:", grades.index("C"))

seat_map = {(1, "A"): "Anika", (1, "B"): "Farah"}
print("Seat 1A belongs to:", seat_map[(1, "A")])

# %% [markdown]
# ### 📝 Practice — Tuples

# %%
# ------------------------------------------------------------- #
# 🔹 2. TUPLES — PRACTICE
# ------------------------------------------------------------- #

college_location = (17.4933, 78.3915)   # (latitude, longitude)

# TODO 1: Unpack college_location into lat and lon


# TODO 2: Write get_dimensions() returning (width, height) e.g. (30, 20), then unpack it


exam_slots = ("Morning", "Afternoon", "Morning", "Evening", "Morning")

# TODO 3: Count how many exams are in the "Morning" slot


# TODO 4: Find the index of the first "Evening" slot


print("Latitude:", lat, "Longitude:", lon)
print("Width x Height:", width, "x", height)

# %% [markdown]
# ## 3️⃣ Dictionaries
# *(see Definitions.md → Dictionaries for the why/when/function table)*

# %%
# ------------------------------------------------------------- #
# 🔹 3. DICTIONARIES — DEMO
# ------------------------------------------------------------- #

marks = {"Anika": 88, "Bhavya": 92, "Chetan": 76}

marks["Divya"] = 95
marks["Chetan"] = 80

score = marks.get("Ravi", "Not graded yet")
print("Ravi's score:", score)

if "Anika" in marks:
    print("Anika's mark is on record:", marks["Anika"])

for name, mark in marks.items():
    print(f"{name} scored {mark}")

average = sum(marks.values()) / len(marks)
print("Class average:", round(average, 2))

marks.pop("Bhavya")
print("After withdrawal:", marks)

new_batch = {"Esha": 89, "Farah": 91}
marks.update(new_batch)
print("After merging new batch:", marks)

# %% [markdown]
# ### 📝 Practice — Dictionaries

# %%
# ------------------------------------------------------------- #
# 🔹 3. DICTIONARIES — PRACTICE
# ------------------------------------------------------------- #

inventory = {"Pen": 50, "Notebook": 30, "Eraser": 100}

# TODO 1: Add a new item "Ruler" with quantity 40


# TODO 2: Increase Eraser stock by 20 (calculate from the existing value, don't hardcode)


# TODO 3: Safely check if "Sharpener" exists; if not, print "Out of stock item"


# TODO 4: Print every item and its quantity using items()


# TODO 5: Find the item with the LOWEST quantity (hint: min() with a key function)


print("Final inventory:", inventory)

# %% [markdown]
# ## 4️⃣ Sets
# *(see Definitions.md → Sets for the why/when/function table and complexity note)*

# %%
# ------------------------------------------------------------- #
# 🔹 4. SETS — DEMO
# ------------------------------------------------------------- #

workshop_a = {"Anika", "Bhavya", "Chetan", "Divya"}
workshop_b = {"Chetan", "Divya", "Esha", "Farah"}

workshop_a.add("Anika")
print("Workshop A (no duplicate added):", workshop_a)

all_students = workshop_a | workshop_b
print("All students (union):", all_students)

both_workshops = workshop_a & workshop_b
print("Students in both (intersection):", both_workshops)

only_a = workshop_a - workshop_b
print("Only in Workshop A (difference):", only_a)

print("Is Farah in Workshop A?", "Farah" in workshop_a)

workshop_a.discard("Bhavya")
print("After discard:", workshop_a)

# %% [markdown]
# ### 📝 Practice — Sets

# %%
# ------------------------------------------------------------- #
# 🔹 4. SETS — PRACTICE
# ------------------------------------------------------------- #

python_club = {"Anika", "Chetan", "Esha", "Farah"}
ai_club = {"Chetan", "Divya", "Farah", "Ganesh"}

# TODO 1: Find all students in EITHER club (union)


# TODO 2: Find students in BOTH clubs (intersection)


# TODO 3: Find students ONLY in python_club (not in ai_club)


# TODO 4: Add "Harini" to python_club (one-item add)


# TODO 5: Check whether "Ganesh" is in python_club using 'in'


print("Python Club now:", python_club)

# %% [markdown]
# ## 5️⃣ File Handling
# *(see Definitions.md → File Handling for the why/when/function table)*

# %%
# ------------------------------------------------------------- #
# 🔹 5. FILE HANDLING — DEMO
# ------------------------------------------------------------- #

with open("student_report.txt", "w") as f:
    f.write("Bootcamp Student Report\n")
    f.write("========================\n")
    lines = ["Anika: 88\n", "Bhavya: 92\n", "Chetan: 76\n"]
    f.writelines(lines)

with open("student_report.txt", "a") as f:
    f.write("Divya: 95 (late entry)\n")

with open("student_report.txt", "r") as f:
    full_content = f.read()
print("----- Full file content -----")
print(full_content)

with open("student_report.txt", "r") as f:
    all_lines = f.readlines()
print("Number of lines in file:", len(all_lines))

with open("student_report.txt", "r") as f:
    first_line = f.readline()
print("First line only:", first_line.strip())

# %%
# ------------------------------------------------------------- #
# 🔹 5. FILE HANDLING — MISSING FILE (try/except)
# ------------------------------------------------------------- #

try:
    with open("does_not_exist.txt", "r") as f:
        content = f.read()
except FileNotFoundError:
    print("That file doesn't exist yet -- creating it now with default content.")
    with open("does_not_exist.txt", "w") as f:
        f.write("This file was just created.\n")

with open("does_not_exist.txt", "r") as f:
    print("Content now:", f.read().strip())

# %% [markdown]
# ### 📝 Practice — File Handling

# %%
# ------------------------------------------------------------- #
# 🔹 5. FILE HANDLING — PRACTICE
# ------------------------------------------------------------- #

# TODO 1: Create/overwrite "attendance.txt" and write the header "Attendance Sheet\n"


# TODO 2: Append 3 attendance lines to the SAME file, e.g.
#         "Anika: Present\n", "Bhavya: Absent\n", "Chetan: Present\n"
#         (use writelines() with the correct mode so the header isn't erased)


# TODO 3: Read the ENTIRE file and print it


# TODO 4: Using readlines(), print how many students were "Present"


# TODO 5 (bonus): Try reading "not_created_yet.txt" in a try/except so it prints
#         "File not found, skipping." instead of crashing

# %% [markdown]
# ---
# ## ✅ End of Lab Manual
#
# You've covered the 5 core building blocks: **Lists, Tuples, Dictionaries, Sets, File Handling.**
#
# See `Python_DataStructures_Definitions.md` for full explanations and the brainstorm challenges.
